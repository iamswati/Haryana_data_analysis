# %%
# This Python 3 environment comes with many helpful analytics libraries installed

import matplotlib as plt
import numpy as np              
import pandas as pd         # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading csv file

# %%
df=pd.read_csv("Haryana covid-19.csv")
df
# Out:
#           Date    State  TotalSamples  Negative  Positive
# 0     4/3/2020  Haryana          1325       938      44.0
# 1     4/7/2020  Haryana          2520      1821     141.0
# 2     4/8/2020  Haryana          2650      1885     153.0
# 3     4/9/2020  Haryana          2964      2017     156.0
# 4    4/10/2020  Haryana          3527      2447     162.0
# ..         ...      ...           ...       ...       ...
# 242  12/4/2020  Haryana       3707439   3407802       NaN
# 243  12/5/2020  Haryana       3745080   3448402       NaN
# 244  12/6/2020  Haryana       3782619   3486902       NaN
# 245  12/7/2020  Haryana       3806770   3516402       NaN
# 246  12/8/2020  Haryana       3842153   3555002       NaN
#
# [247 rows x 5 columns]

# %%
df.shape
# Out:
# (247, 5)

# %%
df.describe()
# Out:
#        TotalSamples      Negative      Positive
# count  2.470000e+02  2.470000e+02    147.000000
# mean   1.162464e+06  1.081472e+06  17381.061224
# std    1.153043e+06  1.070895e+06  20021.155309
# min    1.325000e+03  9.380000e+02     44.000000
# 25%    1.437050e+05  1.346195e+05    786.500000
# 50%    7.130610e+05  6.672440e+05   9218.000000
# 75%    2.117002e+06  1.972728e+06  30146.500000
# max    3.842153e+06  3.555002e+06  76549.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          247 non-null    object
#  1   State         247 non-null    object
#  2   TotalSamples  247 non-null    int64
#  3   Negative      247 non-null    int64
#  4   Positive      147 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.8+ KB

# %%
df.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
date=df[["Date"]]
group_date=date.groupby("Date")
group_date.size()
# Out:
# Date
# 10/1/2020     1
# 10/10/2020    1
# 10/11/2020    1
# 10/12/2020    1
# 10/13/2020    1
#              ..
# 9/5/2020      1
# 9/6/2020      1
# 9/7/2020      1
# 9/8/2020      1
# 9/9/2020      1
# Length: 247, dtype: int64

# %%
df["Date"] =pd.to_datetime(df["Date"])
df["Date"]
# Out:
# 0     2020-04-03
# 1     2020-04-07
# 2     2020-04-08
# 3     2020-04-09
# 4     2020-04-10
#          ...
# 242   2020-12-04
# 243   2020-12-05
# 244   2020-12-06
# 245   2020-12-07
# 246   2020-12-08
# Name: Date, Length: 247, dtype: datetime64[ns]

# %%
df["Date"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 242    2020
# 243    2020
# 244    2020
# 245    2020
# 246    2020
# Name: Date, Length: 247, dtype: int64

# %%
df["Date"].dt.month
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 242    12
# 243    12
# 244    12
# 245    12
# 246    12
# Name: Date, Length: 247, dtype: int64

# %%
df["Date"].dt.day
# Out:
# 0       3
# 1       7
# 2       8
# 3       9
# 4      10
#        ..
# 242     4
# 243     5
# 244     6
# 245     7
# 246     8
# Name: Date, Length: 247, dtype: int64

# %%
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month
df["day"] = df["Date"].dt.day
df
# Out:
#           Date    State  TotalSamples  Negative  Positive  year  month  day
# 0   2020-04-03  Haryana          1325       938      44.0  2020      4    3
# 1   2020-04-07  Haryana          2520      1821     141.0  2020      4    7
# 2   2020-04-08  Haryana          2650      1885     153.0  2020      4    8
# 3   2020-04-09  Haryana          2964      2017     156.0  2020      4    9
# 4   2020-04-10  Haryana          3527      2447     162.0  2020      4   10
# ..         ...      ...           ...       ...       ...   ...    ...  ...
# 242 2020-12-04  Haryana       3707439   3407802       NaN  2020     12    4
# 243 2020-12-05  Haryana       3745080   3448402       NaN  2020     12    5
# 244 2020-12-06  Haryana       3782619   3486902       NaN  2020     12    6
# 245 2020-12-07  Haryana       3806770   3516402       NaN  2020     12    7
# 246 2020-12-08  Haryana       3842153   3555002       NaN  2020     12    8
#
# [247 rows x 8 columns]

# %%
sns.distplot(df.TotalSamples, kde=True)
# Out:
# <AxesSubplot:xlabel='TotalSamples', ylabel='Density'>

# %%
sns.distplot(df.Negative,kde=False)
# Out:
# <AxesSubplot:xlabel='Negative'>

# %%
sns.countplot(df['Positive'])
# Out:
# <AxesSubplot:xlabel='Positive', ylabel='count'>

# %%
sns.boxplot(x='Negative',y='Positive',data=df)
# Out:
# <AxesSubplot:xlabel='Negative', ylabel='Positive'>
