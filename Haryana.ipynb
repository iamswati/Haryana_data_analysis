# %% [markdown]
# # Haryana - EDA
# ### This NoteBook starts with exploratory data analysis for the district Haryana, India. The data contains various features regarding the COVID-19 outbreak like Date, TotalSamples, etc

# %%
# Importing required libraries

# Matplotlib is a low level graph plotting library in python that serves as a visualization utility
import matplotlib.pyplot as plt
import matplotlib as plt
import numpy as np          # linear algebra      
import pandas as pd         # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading CSV File
df=pd.read_csv("Haryana covid-19.csv")
df
# Out:
#           Date    State  TotalSamples  Negative  Positive
# 0     4/3/2020  Haryana          1325       938      44.0
# 1     4/7/2020  Haryana          2520      1821     141.0
# 2     4/8/2020  Haryana          2650      1885     153.0
# 3     4/9/2020  Haryana          2964      2017     156.0
# 4    4/10/2020  Haryana          3527      2447     162.0
# ..         ...      ...           ...       ...       ...
# 242  12/4/2020  Haryana       3707439   3407802       NaN
# 243  12/5/2020  Haryana       3745080   3448402       NaN
# 244  12/6/2020  Haryana       3782619   3486902       NaN
# 245  12/7/2020  Haryana       3806770   3516402       NaN
# 246  12/8/2020  Haryana       3842153   3555002       NaN
#
# [247 rows x 5 columns]

# %%
# View shape of data - rows and columns
df.shape
# Out:
# (247, 5)

# %%
# describe the data
df.describe()
# Out:
#        TotalSamples      Negative      Positive
# count  2.470000e+02  2.470000e+02    147.000000
# mean   1.162464e+06  1.081472e+06  17381.061224
# std    1.153043e+06  1.070895e+06  20021.155309
# min    1.325000e+03  9.380000e+02     44.000000
# 25%    1.437050e+05  1.346195e+05    786.500000
# 50%    7.130610e+05  6.672440e+05   9218.000000
# 75%    2.117002e+06  1.972728e+06  30146.500000
# max    3.842153e+06  3.555002e+06  76549.000000

# %%
# Getting data-type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          247 non-null    object
#  1   State         247 non-null    object
#  2   TotalSamples  247 non-null    int64
#  3   Negative      247 non-null    int64
#  4   Positive      147 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.8+ KB

# %%
# View columns
df.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
# Convert the Integers to Floats Data Type

df['TotalSamples'] = df['TotalSamples'].astype(float)
df['Negative'] = df['Negative'].astype(float)

# %%
# Getting data-type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          247 non-null    object
#  1   State         247 non-null    object
#  2   TotalSamples  247 non-null    float64
#  3   Negative      247 non-null    float64
#  4   Positive      147 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 9.8+ KB

# %%
#counting number of null values
df.isnull().sum()
# Out:
# Date              0
# State             0
# TotalSamples      0
# Negative          0
# Positive        100
# dtype: int64

# %%
# split date 
date=df[["Date"]]
group_date=date.groupby("Date")
group_date.size()
# Out:
# Date
# 10/1/2020     1
# 10/10/2020    1
# 10/11/2020    1
# 10/12/2020    1
# 10/13/2020    1
#              ..
# 9/5/2020      1
# 9/6/2020      1
# 9/7/2020      1
# 9/8/2020      1
# 9/9/2020      1
# Length: 247, dtype: int64

# %%
df["Date"] =pd.to_datetime(df["Date"])
df["Date"]
# Out:
# 0     2020-04-03
# 1     2020-04-07
# 2     2020-04-08
# 3     2020-04-09
# 4     2020-04-10
#          ...
# 242   2020-12-04
# 243   2020-12-05
# 244   2020-12-06
# 245   2020-12-07
# 246   2020-12-08
# Name: Date, Length: 247, dtype: datetime64[ns]

# %%
df["Date"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 242    2020
# 243    2020
# 244    2020
# 245    2020
# 246    2020
# Name: Date, Length: 247, dtype: int64

# %%
df["Date"].dt.month
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 242    12
# 243    12
# 244    12
# 245    12
# 246    12
# Name: Date, Length: 247, dtype: int64

# %%
df["Date"].dt.day
# Out:
# 0       3
# 1       7
# 2       8
# 3       9
# 4      10
#        ..
# 242     4
# 243     5
# 244     6
# 245     7
# 246     8
# Name: Date, Length: 247, dtype: int64

# %%
# New columns are created- year, month, and day
df["year"] = df["Date"].dt.year
df["month"] = df["Date"].dt.month
df["day"] = df["Date"].dt.day
df
# Out:
#           Date    State  TotalSamples   Negative  Positive  year  month  day
# 0   2020-04-03  Haryana        1325.0      938.0      44.0  2020      4    3
# 1   2020-04-07  Haryana        2520.0     1821.0     141.0  2020      4    7
# 2   2020-04-08  Haryana        2650.0     1885.0     153.0  2020      4    8
# 3   2020-04-09  Haryana        2964.0     2017.0     156.0  2020      4    9
# 4   2020-04-10  Haryana        3527.0     2447.0     162.0  2020      4   10
# ..         ...      ...           ...        ...       ...   ...    ...  ...
# 242 2020-12-04  Haryana     3707439.0  3407802.0       NaN  2020     12    4
# 243 2020-12-05  Haryana     3745080.0  3448402.0       NaN  2020     12    5
# 244 2020-12-06  Haryana     3782619.0  3486902.0       NaN  2020     12    6
# 245 2020-12-07  Haryana     3806770.0  3516402.0       NaN  2020     12    7
# 246 2020-12-08  Haryana     3842153.0  3555002.0       NaN  2020     12    8
#
# [247 rows x 8 columns]

# %% [markdown]
# ### Total Number of samples, negative cases and positive cases

# %%
tnocr=df["TotalSamples"].sum(axis = 0, skipna = True)
print("Total Number of samples:", tnocr)
# Out:
# Total Number of samples: 287128625.0

# %%
tnocr=df["Negative"].sum(axis = 0, skipna = True)
print("Total Number of negative cases:", tnocr)
# Out:
# Total Number of negative cases: 267123462.0

# %%
tnocr=df["Positive"].sum(axis = 0, skipna = True)
print("Total Number of positive cases:", tnocr)
# Out:
# Total Number of positive cases: 2555016.0

# %%
sns.histplot(x=df.TotalSamples, kde=True).set_title("Plot Distribution of TotalSamples")
# Out:
# Text(0.5, 1.0, 'Plot Distribution of TotalSamples')

# %%
sns.histplot(x=df.Negative, kde=True).set_title("Plot Distribution of Negative")
# Out:
# Text(0.5, 1.0, 'Plot Distribution of Negative')

# %%
sns.histplot(x=df.Positive, kde=True).set_title("Plot Distribution of Positive")
# Out:
# Text(0.5, 1.0, 'Plot Distribution of Positive')

# %% [markdown]
# ### Plot line graph- TotalSamples, Positive cases and Negative cases with respect to Date

# %%
sns.lineplot(x=df.Date,y='TotalSamples',data=df).set_title("TotalSamples vs date for Haryana")
# Out:
# Text(0.5, 1.0, 'TotalSamples vs date for Haryana')

# %%
sns.lineplot(x=df.Date,y='Negative',data=df).set_title("Negative cases vs date for Haryana")
# Out:
# Text(0.5, 1.0, 'Negative cases vs date for Haryana')

# %%
sns.lineplot(x=df.Date,y='Positive',data=df).set_title("Positive cases vs date for Haryana")
# Out:
# Text(0.5, 1.0, 'Positive cases vs date for Haryana')

# %%
sns.lineplot(x=df.Negative,y='Positive',data=df).set_title("Positive cases vs Negative cases for Haryana")
# Out:
# Text(0.5, 1.0, 'Positive cases vs Negative cases for Haryana')

# %%
df_corr = df[['Date', 'TotalSamples', 'Negative', 'Positive']].corr()
df_corr
# Out:
#               TotalSamples  Negative  Positive
# TotalSamples      1.000000  0.999931  0.997320
# Negative          0.999931  1.000000  0.997071
# Positive          0.997320  0.997071  1.000000

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.heatmap(df_corr, vmin=0, vmax=1,annot=True)
# Out:
# <AxesSubplot:>
